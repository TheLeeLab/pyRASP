# %%
import sys

sys.path.append("..")  # Adds higher directory to python modules path.

import os
from src import RASPRoutines

RASP = RASPRoutines.RASP_Routines()
import numpy as np
import polars as pl

# %%
area_pixels = 200; pixel_size_nm = 110; area_micrometers = area_pixels * (pixel_size_nm / 1000)**2; side_length_micrometers = area_micrometers**0.5; print(f"Area: {area_micrometers:.2f} µm², Side length: {side_length_micrometers:.2f} µm")
# Out:
# Area: 2.42 µm², Side length: 1.56 µm

# %%
"""
Redo colocalisation analyses of spots above a photon threshold in an
analysis file.

        Args:
            analysis_file (str): The analysis file to be re-done.
            threshold (float): The photon threshold
            protein_string (str): string of analysed protein
            lo_string (str): string of large object to analyse
            analysis_type (str, optional): Type of analysis to perform. Options are:
                - "lo_to_spot": Calculate spot to large object metrics.
                - "lo_to_cell": Calculate large object to cell coincidence.
                Default is "spot_to_cell".
            imtype (str): image type
            blur_degree (int): blur degree for colocalisation analysis
            calc_clr (boolean): Calculate the clr, yes/no.
            lower_cell_size_threshold (float): lower threshold of cell size
            upper_cell_size_threshold (float): upper threshold of cell size
            lower_lo_size_threshold (float): lower threshold of lo size
            upper_lo_size_threshold (float): upper threshold of lo size
            z_project_first (list of boolean): z project instructions for cell/protein size threshold
            cell_threshold (float): intensity value cell should be above

"""

analysis_file = os.path.abspath(
    r"F:\20240913_Isoform_syn211_second_run\data_analysis\largeobject_analysis.csv"
)  # example file, replace as you wish. Always input as the absolute path of a raw string
threshold = 650.0
cell_threshold = 850.0
protein_string = "C0"
lo_string = "C0"
cell_string = "C1"
upper_cell_size_threshold = np.inf
upper_lo_size_threshold = np.inf

analysis_type = 'lo_to_cell'
blur_degree = 1
imtype='.tif'
calc_clr = False
z_project_first = [False, False]

lower_lo_thresholds = np.arange(0, 150, 25)
lower_cell_thresholds = np.arange(0, 2500, 250)

for lower_cell_size_threshold in lower_cell_thresholds:
    print("lower cell size threshold is "+str(int(lower_cell_size_threshold)))
    for lower_lo_size_threshold in lower_lo_thresholds:
        print("lower lo size threshold is "+str(int(lower_lo_size_threshold)))
        lo_analysis_AT, spot_analysis_AT = RASP.lo_colocalise_wrapper(
            analysis_file,
            threshold,
            protein_string=protein_string,
            lo_string=lo_string,
            cell_string=cell_string,
            analysis_type=analysis_type,
            imtype=imtype,
            blur_degree=blur_degree,
            calc_clr=calc_clr,
            lower_cell_size_threshold=lower_cell_size_threshold,
            upper_cell_size_threshold=upper_cell_size_threshold,
            lower_lo_size_threshold=lower_lo_size_threshold,
            upper_lo_size_threshold=upper_lo_size_threshold,
            z_project_first=z_project_first,
            cell_threshold=cell_threshold,
        )
        del lo_analysis_AT
        del spot_analysis_AT
# Out:
# lower cell size threshold is 0
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 323.587 s
# lower lo size threshold is 50File 68/68    Time elapsed: 339.441 s
# lower lo size threshold is 75File 68/68    Time elapsed: 339.093 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 333.110 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 221.169 s
# lower cell size threshold is 250e 68/68    Time elapsed: 130.475 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 260.898 s
# lower lo size threshold is 50File 68/68    Time elapsed: 260.067 s
# lower lo size threshold is 75File 68/68    Time elapsed: 260.072 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 256.186 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 166.957 s
# lower cell size threshold is 500e 68/68    Time elapsed: 98.588 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 246.571 s
# lower lo size threshold is 50File 68/68    Time elapsed: 245.562 s
# lower lo size threshold is 75File 68/68    Time elapsed: 245.412 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 241.968 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 156.421 s
# lower cell size threshold is 750e 68/68    Time elapsed: 92.223 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 239.708 s
# lower lo size threshold is 50File 68/68    Time elapsed: 238.653 s
# lower lo size threshold is 75File 68/68    Time elapsed: 238.248 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 234.727 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 151.775 s
# lower cell size threshold is 1000 68/68    Time elapsed: 89.365 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 235.141 s
# lower lo size threshold is 50File 68/68    Time elapsed: 234.124 s
# lower lo size threshold is 75File 68/68    Time elapsed: 234.166 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 230.214 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 148.799 s
# lower cell size threshold is 1250 68/68    Time elapsed: 87.604 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 232.587 s
# lower lo size threshold is 50File 68/68    Time elapsed: 231.919 s
# lower lo size threshold is 75File 68/68    Time elapsed: 232.011 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 228.175 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 147.479 s
# lower cell size threshold is 1500 68/68    Time elapsed: 86.921 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 230.145 s
# lower lo size threshold is 50File 68/68    Time elapsed: 222.957 s
# lower lo size threshold is 75File 68/68    Time elapsed: 222.232 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 218.613 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 141.683 s
# lower cell size threshold is 1750 68/68    Time elapsed: 83.189 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 223.525 s
# lower lo size threshold is 50File 68/68    Time elapsed: 218.036 s
# lower lo size threshold is 75File 68/68    Time elapsed: 217.914 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 214.684 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 139.015 s
# lower cell size threshold is 2000 68/68    Time elapsed: 81.586 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 215.510 s
# lower lo size threshold is 50File 68/68    Time elapsed: 210.121 s
# lower lo size threshold is 75File 68/68    Time elapsed: 210.028 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 207.977 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 134.788 s
# lower cell size threshold is 2250 68/68    Time elapsed: 79.464 s
# lower lo size threshold is 0
# lower lo size threshold is 25File 68/68    Time elapsed: 210.696 s
# lower lo size threshold is 50File 68/68    Time elapsed: 204.290 s
# lower lo size threshold is 75File 68/68    Time elapsed: 204.747 s
# lower lo size threshold is 100ile 68/68    Time elapsed: 202.409 s
# lower lo size threshold is 125ile 68/68    Time elapsed: 131.853 s
# Computing colocalisation     File 68/68    Time elapsed: 77.991 s
